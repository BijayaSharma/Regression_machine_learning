# %% [markdown]
# # Introduction is in the next file :

# %% [markdown]
# # Fitting the best fit line :

# %% [markdown]
# when working with linear regression, our main goal is to find the best fit line that means the error between predicted values and actual values should be minimized. The best fit line will have the least error.
#
# The different values for weights or the coefficients of lines (a0, a1) gives a different line of regression, so we need to calculate the best values for a0 & a1 to find the best fit line, so to calculate this we use cost function

# %% [markdown]
# # Cost function

# %% [markdown]
# 1. The different values for weights or coefficients of lines (a0, a1) gives the different line of regression, and the cost    of function is used to estimate the values of the coefficients for the best fit line.
#
# 2. cost function optimizes the regression coefficients or weights. It measures how a linear regression model is performing.
#
# 3. We can use the cost function to find the accuracy of the mapping function, which maps the input variable to the output      variable. This mappling function is also known as Hypothesis function.
#
# For linear regression, we use the Mean Squared Error (MSE) cost function, which is the average of squared error occured between the predicted values & actual values. It can be written as

# %% [markdown]
# ![lslslfllggggr.gif](attachment:lslslfllggggr.gif)

# %% [markdown]
# # Gradient Descent

# %% [markdown]
# 1. It is used to minimize the MSE by calculating the gradient of the cost function.
#
# 2. A regression model uses gradient descent to update the coefficients of the line by reducing the cost function
#
# 3. It is done by a random selection of values of coefficients and then iteratively update the values to reach the              performance

# %% [markdown]
# # Model Performance :

# %% [markdown]
# # 1. R-squared method

# %% [markdown]
# 1. It is a statistical method that determines the goodness of fit.
#
# 2. measures the relationship between the dependent & independent variables on a scale of 0-100%
#
# 3. The high value of R-square determines the less difference between the predicted values & actual values & hence              represents the good model.
#
# 4. It is also called coefficient of determination, or coefficient of multiple determination for multiple regression.
#
# 5. It is calculated by the following formula :

# %% [markdown]
# ![sldlflff.gif](attachment:sldlflff.gif)

# %% [markdown]
# # Assumptions of Linear Regression

# %% [markdown]
# Below are some important assumptions of Linear Regression. These are the some formal checks while building a Linear Regression model, it ensures to get the best possible result from the give dataset.

# %% [markdown]
# 1. Linear relationship between features & target
#
#
#
# 2. Small or no multicollinearity between the features :
#     Multi-collinearity means high-corrleations between the independent variables. Due to this, it may be difficult to find     true relationship between the predictors and target variables. Or we can say, it is difficult to determine which
#     predictor variable is affecting the target variable and which is not.
#
#
# 3. Homoscedasticity Assumptions :
#     Homoscedasticity is a situation when the error term is same for all the values of                                           independent variables. With homoscdasticity, there should be no clear pattern distributon                                   of data in the scatter plot.
#
#
#
#
# 4. Normal distribution of error terms :
#      Linear regression assumes that the error term should follow the normal distribution pattern. If error terms are not        normally distributed, then confidence intervals will become either too wide or too narrow, which cause difficulties in      finding coefficient. It can be checked by using the q-q plot. If the plot shows the straight line without any
#      deviationm, which means the error is normally distributed.
#
#
# 5. No autocorrelation :
#     The linear regression model assumes no autocorrlation in error terms. If there will be any correlation in the error         term, then it will drastically reduce the accuracy of the model. Autocorrelation usually occurs if there is a               dependency between residual errors.

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# Dependent variable must be continuous/real value while independent variable might be continuous or categorical variables.

# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# Some key points about MLR:
#
# 1. For MLR, the dependent or target variable(Y) must be the continuous/real, but the predictor or independent variable may be of continuous or categorical form.
# 2.Each feature variable must model the linear relationship with the dependent variable.
# 3.MLR tries to fit a regression line through a multidimensional space of data-points.
#
#
#
# MLR equation:
#
#
# In Multiple Linear Regression, the target variable(Y) is a linear combination of multiple predictor variables x1, x2, x3, ...,xn. Since it is an enhancement of Simple Linear Regression,

# %% [markdown]
# Assumptions for Multiple Linear Regression:
#
#
# 1. A linear relationship should exist between the Target and predictor variables.
# 2. The regression residuals must be normally distributed.
# 3. MLR assumes little or no multicollinearity (correlation between the independent variable) in data.

# %% [markdown]
# https://www.javatpoint.com/multiple-linear-regression-in-machine-learning  for MLR example

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# https://www.javatpoint.com/machine-learning-polynomial-regression
