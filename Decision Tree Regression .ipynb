# %% [markdown]
# Decision trees are a common way of representing the decision-making process through a branching, tree-like structure. A decision tree algorithm will be used to split dataset features through a cost function.
#
# => cost function optimizes regression coefficient or weights. it is used to measure how the model is performing. we can use cost function to find the accuracy of the mapping function, which maps input variable to the output variable.
#
# = The decision tree is grown before being optimized to remove branches that may use irrelevant features, a process called pruning. Parameters such as the depth of the decision tree can also be set, to lower the risk of overfitting or an overly complex treee.
#
# = The majority of decision tree in machine learning will be used for classification problems, to categorise objects against learned features. The main benefits of using it in machine learning is its simplicity, as the decision-making process is easy to visualize and understand. However, it might become overly complex by generating very granular branches so pruning of the trees structure is often necessity.

# %% [markdown]
# 1. It can be used for solving both classification & regression problems
# 2. can solve problems for both categorical (group information with similar characteristics) & numerical data
# 3. It builds a tree-like structure in which each internal node represents the "test" for an attribute, each branch
#    represents the result of the test, & each leaf node represents the final decision or result.
#
# 4. A decision tree is constructed starting from the root node/parent node (dataset), which splits into left & right child
#    nodes (subsets of dataset). These child nodes are further divided into their children node, and themselves become the
#    parent node of those nodes. consider the below image

# %% [markdown]
# # What is a decision tree in machine learning ?

# %% [markdown]
# It is a way of modeling decisions and outcomes, mapping decisions in a branching structure. It is used to calculate the potential success of different series of decisions made to achieve a specific goal.
#
#
#
# Decision trees are a form of predictive modeling, helping to map the different decisions or solutions to a given outcome. It is made up of different nodes. The root node is the start of the decision tree, which is usually the whole dataset within the machine learning. Leaf nodes are the endpoint of a branch, or the final output of a series of decisions. The decision tree won't branch any further from a leaf node. With decision trees in machine learning, the features of the data are internal nodes and the outcome is the leaf node.
#
#
#
# It is an approach used in supervised machine learning, a technique which uses labelled input & output datasets to train the models. The approach is used mainly to slove the classification problems, which is the use of a model to categorize or classify an object. While it is used in regression problems to forecast outputs from unseen data.
#
#
# The resoning behind model's decision-making process is clearer when the model uses a decision tree structure, because each decision branch can be observed.
#
# Classification tress are used for decisions such as yes or no, with a categorical decision variable. Regression trees are used for a continuous outcome variable such as a number.

# %% [markdown]
# # What is a classification tree ?

# %% [markdown]
# In this the model is trained to classify whether data is a part of a known object class. Models are trained to assign class labels to processed data. To solve a classification problem, a model must understand the features that categorise a datapoint into the different class labels. In practice, a classification problem can occur in a range of settings.
#
# Example ::
#     1. classification of documents, image recognition software, or email spam detections.
#
#
#
# A classification tress is a way of structuring a model to classify objects or data. The leaves or endpoint of the branches in a classification tree are the class labels, the point at which the branches stop splitting. The classification tree is generated incrementally, with the overall dataset being broken down into smaller subsets.  It is used when the target variables are discrete or categorical, with branching happening usually through binary partitioning.
#
# For example ::
#     1. each node may branch on a yes or no answer.
#
# Classification trees are used when the target variable is categorical or can be given a specific category such as yes or no. The end point of each branch is one category.

# %% [markdown]
# https://www.javatpoint.com/machine-learning-decision-tree-classification-algorithm

# %% [markdown]
# # Decision Tree Classification Alogrithm

# %% [markdown]
# 1. In decision tree there are 2 nodes, which are the decision node and leaf node. Decision nodes are used to make any decision and have multiple branches, where as leaf nodes are the output of those decisions and don't contain any further branches.
#
#
# 2. The decisions or the test are performed on the basis of features of the given dataset.
#
# 3. It is called a decision tree because, similar to a tree, it starts with the root node, which expands on further branches and constructs a tree-like structure.
#
# 4. In order to build a tree, we use the CART algorithm, which stands for Classifications and Regression Tree algorithm.
#
#
# 5. It simply ask a question, and based on the answer (yes/no), it further split the tree into subtrees.

# %% [markdown]
# ![lslslsl.gif](attachment:lslslsl.gif)

# %% [markdown]
# # Why use Decision Trees ?

# %% [markdown]
# 1. It usually mimic human thinking ability while making a decisions, so it is easy to understand.
#
# 2. The logic behind the decision tree can be easily understood because it shows a tree-like structure.

# %% [markdown]
# # Decision Tree Terminologies

# %% [markdown]
# 1. ROOT Node : from where the decision tree starts. Represents the entire dataset, which further gets divided into 2 or more homogenous set
#
# 2. Leaf Node : final output node, the tree cannot be segregated further after getting a leaf node.
#
# 3. Splitting : the process of dividing the decision node/root node into sub-nodes according to the given conditions
#
# 4. Branch/Sub Tree : A tree formed by splitting the tree.
#
# 5. Purning : process of removing the unwanted branches from the tree
#
# 6. Parent/child node : The root node of the tree is called the parent node while other nodes are called the child nodes.

# %% [markdown]
# # How does the Decision Tree algorithm work ?

# %% [markdown]
# The algorithm starts from the  root node of the tree. This algorithm compares the values of the root attribute with the record (real dataset) attribute and based on the comparison, follows the branch and jumps to the next node.
#
#
# For the next node, the algorithm again compares the attribute value with the other sub-nodes and move further. It continues the process until it reaches the leaf node of the tree. The complete process can be better understood using the below alogrithm :
#
#
# Attribute is a characteristics or feature that is measured for each observation (like red, yellow, time spent in website etc)
#
# 1. step 1 : Begin the tree with the root node (say S), which contains the complete dataset.
# 2. step 2 : Find the best attribute in the dataset using Attribute Selection Measure (ASM).
# 3. step 3 : Divide the S into subsets that contains possible values for the best attributes.
# 4. step 4 : Generate the decision tree node, which contains the best attribute.
# 5. step 5 : Recursively make new decision trees using the subsets of the dataset created in step-3. Continue this process until a stage is reached where you cannot further classify the nodes & called the final node as a leaf node.

# %% [markdown]
# # Example

# %% [markdown]
# Suppose there is a candidate who has a job offer and wants to decide whether he should accept or reject an offer. So, to solve this problem, the decision tree starts with the root node (Salary attribute by ASM). The root node splits further into the next decision node (distance from the home) and one leaf node based on the correpsonding labels. The next decision node further gets split into one decision node (cab facility) and one leaf node. Finally the decision node splits inot 2 leaf nodes (Accept offer and decline offer). Consider the below diagram :

# %% [markdown]
# ![sldlffkfrq.gif](attachment:sldlffkfrq.gif)

# %% [markdown]
# # Attribute Selection Measures

# %% [markdown]
# While implmenting a decision tree, the main issue arises that how to select the best attribute for the root nod & sub nodes. So to solve such problem there is a technique which is called  as "Attribute selecting measure or ASM". By this measurement, we can easily select the best attribute for the nodes of the tree. There are two popular techniques for ASM, which are :
#
# 1. Information Gain
#
# 2. Gini Index

# %% [markdown]
# 1. Information Gain :
# 1. => It is the measurement of changes in entropy after the segmentation of a dataset based on attribute or measure of decrease in entropy after the dataset is split
# 2. => It calculates how much information a feature provides us about a class.
# 3. => According to the value of information gain, we split the node and build the decision tree.
# 4. => A decision tree algorithm always tries to maximize the value of information gain, and a node/attribute having the highest information gain is split first. It can be calculated using the below formula.

# %% [markdown]
# Entropy is the measure of randomness or unpredictability in the dataset

# %% [markdown]
# ![llssllsf.gif](attachment:llssllsf.gif)

# %% [markdown]
# 2. Gini Index :

# %% [markdown]
# ![llflflfl.gif](attachment:llflflfl.gif)

# %% [markdown]
# ![Screenshot%202022-08-20%20135453.gif](attachment:Screenshot%202022-08-20%20135453.gif)

# %% [markdown]
# # Advantages of the Decision Tree

# %% [markdown]
# 1. It is simple to understand as it follows the same process which a human follow while making any decision in real-life.
#
# 2. Can be useful for solving decision-related problems.
# 3. Helps to think about all the possible outcomes for a problem
# 4. There is less requirement of data cleaning compared to other alogrithm.

# %% [markdown]
# # Disadvantages of the Decision Tree

# %% [markdown]
# 1. The decision tree contains lots of layers, which makes it complex
# 2. It may have an overfitting issue(due to noise in the data), which can be resolved using Random Forest algorithm
# 3. For more class labels, the computational complexity of the decision tree may increase
# 4. High variance : The model can get unstable due to small variation in data

# %% [markdown]
# # Python Implementation of Decision Tree

# %% [markdown]
# 1. Data Pre-processing step
# 2. Fitting a Decision-Tree algorithm to the Training set
# 3. Predictiing the test result
# 4. Test accuracy of the result (Creation of confusion matrix)
# 5. Visualizing the test set result.
